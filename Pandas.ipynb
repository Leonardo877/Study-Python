# %% [markdown]
# # Capturando Pokémons com Pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
import requests

# %%
res = requests.get("https://pokemondb.net/pokedex/all")

# %%
list_result = pd.read_html(res.text)
len(list_result)

# %%
table = list_result[0]
table
# Out:
#        #                         Name            Type  Total   HP  Attack  \
# 0      1                    Bulbasaur     GrassPoison    318   45      49
# 1      2                      Ivysaur     GrassPoison    405   60      62
# 2      3                     Venusaur     GrassPoison    525   80      82
# 3      3        VenusaurMega Venusaur     GrassPoison    625   80     100
# 4      4                   Charmander            Fire    309   39      52
# 5      5                   Charmeleon            Fire    405   58      64
# 6      6                    Charizard      FireFlying    534   78      84
# 7      6    CharizardMega Charizard X      FireDragon    634   78     130
# 8      6    CharizardMega Charizard Y      FireFlying    634   78     104
# 9      7                     Squirtle           Water    314   44      48
# 10     8                    Wartortle           Water    405   59      63
# 11     9                    Blastoise           Water    530   79      83
# ...

# %%
table.info

# %%
# Out:
# <bound method DataFrame.info of        #                         Name            Type  Total   HP  Attack  \
# 0      1                    Bulbasaur     GrassPoison    318   45      49
# 1      2                      Ivysaur     GrassPoison    405   60      62
# 2      3                     Venusaur     GrassPoison    525   80      82
# 3      3        VenusaurMega Venusaur     GrassPoison    625   80     100
# 4      4                   Charmander            Fire    309   39      52
# 5      5                   Charmeleon            Fire    405   58      64
# 6      6                    Charizard      FireFlying    534   78      84
# 7      6    CharizardMega Charizard X      FireDragon    634   78     130
# 8      6    CharizardMega Charizard Y      FireFlying    634   78     104
# 9      7                     Squirtle           Water    314   44      48
# 10     8                    Wartortle           Water    405   59      63
# ...

# %%
table.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  917.000000  917.000000  917.000000  917.000000  917.000000  917.000000
# mean   399.930207  438.146129   69.546347   80.056707   74.532170   73.199564
# std    235.970035  120.350210   26.074785   32.586115   31.237579   33.179584
# min      1.000000  175.000000    1.000000    5.000000    5.000000   10.000000
# 25%    196.000000  330.000000   50.000000   55.000000   50.000000   50.000000
# 50%    395.000000  455.000000   66.000000   75.000000   70.000000   65.000000
# 75%    608.000000  517.000000   80.000000  100.000000   90.000000   95.000000
# max    807.000000  780.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed
# count  917.000000  917.000000
# mean    72.315158   68.496183
# std     27.839761   29.439288
# min     20.000000    5.000000
# 25%     50.000000   45.000000
# 50%     70.000000   65.000000
# 75%     90.000000   90.000000
# ...
